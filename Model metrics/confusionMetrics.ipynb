# %%
from sklearn.metrics import confusion_matrix

# %%
y_true = [1,1,0,0,1,0,1,0,0,0,1]
y_pred = [1,1,0,1,1,0,0,0,0,0,0]

# %%
cm = confusion_matrix(y_true , y_pred)
print(cm)
# Out:
# [[5 1]
#  [2 3]]
