# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv("../Social_Network_Ads.csv")

# %%
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
sns.scatterplot(x="Age", y="Purchased", data=data)
plt.show()

# %%
# seperating the dependant and independant varaible
X = data.drop(columns=["Purchased","EstimatedSalary"], axis=1)
y=data['Purchased']

# %%
X,y
# Out:
# (     Age
#  0     19
#  1     35
#  2     26
#  3     27
#  4     19
#  ..   ...
#  395   46
#  396   51
#  397   50
#  398   36
#  399   49
#
#  [400 rows x 1 columns],
#  0      0
#  1      0
#  2      0
#  3      0
#  4      0
#        ..
#  395    1
#  396    1
#  397    1
#  398    0
#  399    1
#  Name: Purchased, Length: 400, dtype: int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=0,test_size=0.2)

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(X_test, y_test)
# Out:
# 0.9375

# %%
lr.predict([[40]])
# Out:
# c:\Users\Sital\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
sns.scatterplot(x="Age", y="Purchased", data=data)
sns.lineplot(x="Age", y=lr.predict(X), data=data, c="red")
plt.show()
